# %% [markdown]
# ## Fiche projet long de CIT et de découverte des spécialités SI et NSI

# %% [markdown]
# ### Identification :
#
# - Nom : Pouliquen
# - Prenom : Lancelot
# - Classe : 2Gt3
#
# ### Ce que je faisais l'année dernière ? Quoi ? Où ?
#
# Collège St Joseph, option latin et section euro, à Morlaix
#
# ### Quel est mon projet d'orientation ? Dans quel domaine ? Vers quel métier ?
#
# Archéologue

# %% [markdown]
# ### Bilan du projet de la fête de la science :
#
# <img src=https://ericecmorlaix.github.io/2SI-CIT_2025-2026/fds/Diplome.png width=60%>
#
# #### Ce qui a bien fonctionné :
#
# Les primaires ont bien compris les instructions et ont réussi l´objectif.
#
# #### Ce qui a moins bien fonctionné :
#
# Ils avaient du mal à rester concentrer

# %% [markdown]
# ### Pourquoi je choisi de participer à l'AP projet long de CIT et de découverte des spécialités SI et NSI ?
#
# pour développer mes connaissances en informatique
#
# ### Ce que j'envisage d'y faire, quel projet ?
#
# fabriquer un amplificateur de son
#
#
# ### J'illustre le projet, système ou domaine que j'aimerai étudier ?
#
# - [Nom du système](URL d'un site web) : boitier du potentiomètre
#
# ![image du système](URL d'une image du web)
#
# Avancement du projet :
#
# La structure du boitier est faite, reste a faire : adapter des ouvertures en fonction des pieces electroniques.
