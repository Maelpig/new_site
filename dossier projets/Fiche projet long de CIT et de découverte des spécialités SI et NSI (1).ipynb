# %% [markdown]
# ## Fiche projet long de CIT et de découverte des spécialités SI et NSI

# %% [markdown]
# ### Identification :
#
# - Nom : Rouzault
# - Prenom : Alexandre
# - Classe : 2gt3
#
# ### Ce que je faisais l'année dernière ? Quoi ? Où ?
#
# college st jo
#
# ### Quel est mon projet d'orientation ? Dans quel domaine ? Vers quel métier ?
#
# inge/dev informatique

# %% [markdown]
# ### Bilan du projet de la fête de la science :
#
# <img src=https://ericecmorlaix.github.io/2SI-CIT_2025-2026/fds/Diplome.png width=60%>
#
# #### Ce qui a bien fonctionné :
#
#
#
#
# #### Ce qui a moins bien fonctionné :
#
# ...

# %% [markdown]
# ### Pourquoi je choisi de participer à l'AP projet long de CIT et de découverte des spécialités SI et NSI ?
#
# Pour etre ingenieur informatique ou dev informatique
#
# ### Ce que j'envisage d'y faire, quel projet ?
#
# Depuis le début de l'année moi et Yanis avons travaillés sur la construction de robot, puis la construction d'une voiture télécommandé à infrarouge. Maintenant nous allons  essayer de construire une voiture télécommandé à infrarouge à partir de lego."
#
#
# ### J'illustre le projet, système ou domaine que j'aimerai étudier ?
#
# - [site starter kit pour voiture télécommandé à infrarouge](https://www.yahboom.net/study/Building_bit)
#
# Exemple d'un kit pour une voiture télécommandé à infrarouge avec carte BBC:
# ![image du système](data:image/webp;base64,...)
